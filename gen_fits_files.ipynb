# %% [markdown]
# ## Notebook for generating the fits files of a new list of objects
# You will need a .txt file where each line is a TIC ID
# You can find the file on
# /pdo/users/pablomer/Astronet-Triage/h5_to_fits_michelle.py
# or
# /pdo/users/pablomer/FFITools/h5_to_fits_frommichelle.py

# %%
! /sw/python-versions/python-3.11.9/bin/python3 FFITools/h5_to_fits_frommichelle.py -i /pdo/users/pablomer/mnt/tess/astronet/new_events2025_TIC_list.txt -o /pdo/users/pablomer/mnt/tess/new_fit_files -s 85
# Out:
# ^C
# Traceback (most recent call last):
#   File "/pdo/users/pablomer/FFITools/h5_to_fits_frommichelle.py", line 236, in <module>
#     pool.starmap(h5tofits, tasks)
#   File "/sw/python-versions/python-3.11.9/lib/python3.11/multiprocessing/pool.py", line 375, in starmap
#     return self._map_async(func, iterable, starmapstar, chunksize).get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/sw/python-versions/python-3.11.9/lib/python3.11/multiprocessing/pool.py", line 768, in get
#     self.wait(timeout)
#   File "/sw/python-versions/python-3.11.9/lib/python3.11/multiprocessing/pool.py", line 765, in wait
#     self._event.wait(timeout)
#   File "/sw/python-versions/python-3.11.9/lib/python3.11/threading.py", line 629, in wait
#     signaled = self._cond.wait(timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/sw/python-versions/python-3.11.9/lib/python3.11/threading.py", line 327, in wait
#     waiter.acquire()
# KeyboardInterrupt

# %% [markdown]
# or just run on terminal
# /sw/python-versions/python-3.11.9/bin/python3 FFITools/h5_to_fits_frommichelle.py -i /pdo/users/pablomer/mnt/tess/astronet/new_events2025_TIC_list.txt -o /pdo/users/pablomer/mnt/tess/new_fit_files -s 85
