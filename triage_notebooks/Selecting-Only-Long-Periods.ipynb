# %%
import pandas as pd
from pathlib import Path

# %%
#load a .csv file with pandas
path = Path("mnt/tess/astronet/tces-vetting-v01-tois-triageJs-nocentroid-test.csv")
data = pd.read_csv(path)

# %%
print('Original test set size',data.shape)
print('Modified test set size',data[data['Per']>=20].shape)
# Out:
# Original test set size (939, 28)
# Modified test set size (43, 28)

# %%
long_periods_test_set=data[data['Per']>=20]

# %%
long_periods_test_set.to_csv("mnt/tess/astronet/tces-vetting-v01-tois-triageJs-nocentroid-test-long.csv", index=False)
